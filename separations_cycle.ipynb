# %% [markdown]
# ## With diversion

# %%
simulation = {
    'simulation': {
        'control': {
            'duration': '365', 
            'startmonth': '1', 
            'startyear': '2021', 
            'decay': 'never', 
            'explicit_inventory': 'true'
        }, 
        'archetypes': {
            'spec': [
                {'lib': 'cycamore', 'name': 'Enrichment'}, 
                {'lib': 'cycamore', 'name': 'Reactor'}, 
                {'lib': 'cycamore', 'name': 'Source'},
                {'lib': 'cycamore', 'name': 'Sink'}, 
                {'lib': 'cycamore', 'name': 'Separations'}
                {'lib': 'agents', 'name': 'NullRegion'}, 
                {'lib': 'agents', 'name': 'NullInst'}
            ]}, 
        'facility': [
            {'name': 'UraniumMine', 
             'config': {'Source': {'outcommod': 'c_uore', 'outrecipe': 'r_nat_u', 'throughput': '1'}}}, 
            {'name': 'LEUenrich', 
             'config': {'Enrichment': {'feed_commod': 'c_uore', 'feed_recipe': 'r_nat_u', 
                                       'product_commod': 'c_leu', 'tails_commod': 'tails', 
                                       'max_enrich': '0.041'}}}, 
            {'name': 'HEUenrich', 
             'config': {'Enrichment': {'feed_commod': 'c_leu', 'feed_recipe': 'r_nat_u', 
                                       'product_commod': 'c_heu', 'tails_commod': 'tails', 
                                       'max_enrich': '0.9'}}},
            {'name': 'reactor', 
             'config': {'Reactor': {'fuel_incommods': {'val': 'c_leu'}, 
                                    'fuel_inrecipes': {'val': 'r_leu'}, 
                                    'fuel_outcommods': {'val': 'c_spent_leu'}, 
                                    'fuel_outrecipes': {'val': 'r_leu_spent'}, 
                                    'cycle_time': '180', 'refuel_time': '30', 
                                    'assem_size': '3300', 'n_assem_core': '3', 
                                    'n_assem_batch': '1', 'power_cap': '100'}}}, 
            {'name': 'separations', 
             'config': {'Separations': {'feed_commods': {'val': 'c_spent_leu'}, 
                                        'feedbuf_size': 50.0}, 
                                        "streams": {
                                          "item": [{
                                            "commod": "c_placeholder1",
                                            "info": {
                                              "buf_size": 0.0,
                                              "efficiencies": {
                                                "item": [{
                                                  "comp": 0,
                                                  "eff": 0.0},
                                                  {"comp": 0,
                                                  "eff": 0.0},
                                              ]}
                                              }
                                            },
                                            {"commod": "c_placeholder2",
                                            "info": {
                                              "buf_size": 0.0,
                                              "efficiencies": {
                                                "item": [{
                                                  "comp": 0,
                                                  "eff": 0.0},
                                                  {"comp": 0,
                                                  "eff": 0.0},
                                              ]}
                                              }
                                            },
                                        ]}}}
            {'name': 'SpentFuelSink', 
             'config': {'Sink': {'in_commods': {'val': 'c_spent_leu'}}}}, 
            {'name': 'HEUSink', 
             'config': {'Sink': {'in_commods': {'val': 'c_heu'}, 'capacity': '10', 'recipe_name': 'r_heu'}}}
        ], 
        'region': {'name': 'SimpleHiderRegion', 
                   'config': {'NullRegion': None}, 
                   'institution': {'name': 'inst', 
                                   'initialfacilitylist': {'entry': [{'number': 1, 'prototype': 'UraniumMine'}, 
                                                                     {'number': 1, 'prototype': 'LEUenrich'}, 
                                                                     {'number': 1, 'prototype': 'reactor'}, 
                                                                     {'number': 1, 'prototype': 'separations'},
                                                                     {'number': 1, 'prototype': 'SpentFuelSink'}, 
                                                                     {'number': 1, 'prototype': 'LEUtoHEUenrich'}, 
                                                                     {'number': 1, 'prototype': 'HEUSink'}]}, 
                                   'config': {'NullInst': None}}
                  }, 
        'recipe': [
            {'name': 'r_nat_u', 'basis': 'mass', 
             'nuclide': [{'id': '92235', 'comp': '0.00711'}, 
                         {'id': '92238', 'comp': '0.99289'}]}, 
            {'name': 'r_heu', 'basis': 'mass', 
             'nuclide': [{'id': '92235', 'comp': '0.9'}, 
                         {'id': '92238', 'comp': '0.1'}]}, 
            {'name': 'r_leu', 'basis': 'mass', 
             'nuclide': [{'id': '92235', 'comp': '0.04'}, 
                         {'id': '92238', 'comp': '0.96'}]}, 
            {'name': 'r_leu_spent', 'basis': 'mass', 
             'nuclide': [{'id': '92235', 'comp': '0.01'}, 
                         {'id': '92238', 'comp': '0.94'}, 
                         {'id': '94239', 'comp': '0.01'}, 
                         {'id': '55135', 'comp': '0.3'}]}
        ]
    }
}

# %% [markdown]
# ## Without diversion

# %%
simulation = {
    'simulation': {
        'control': {
            'duration': '365', 
            'startmonth': '1', 
            'startyear': '2021', 
            'decay': 'never', 
            'explicit_inventory': 'true'
        }, 
        'archetypes': {
            'spec': [
                {'lib': 'cycamore', 'name': 'Enrichment'}, 
                {'lib': 'cycamore', 'name': 'Reactor'}, 
                {'lib': 'cycamore', 'name': 'Source'},
                {'lib': 'cycamore', 'name': 'Sink'}, 
                {'lib': 'cycamore', 'name': 'Separations'}
                {'lib': 'agents', 'name': 'NullRegion'}, 
                {'lib': 'agents', 'name': 'NullInst'}
            ]}, 
        'facility': [
            {'name': 'UraniumMine', 
             'config': {'Source': {'outcommod': 'c_uore', 'outrecipe': 'r_nat_u', 'throughput': '1'}}}, 
            {'name': 'LEUenrich', 
             'config': {'Enrichment': {'feed_commod': 'c_uore', 'feed_recipe': 'r_nat_u', 
                                       'product_commod': 'c_leu', 'tails_commod': 'tails', 
                                       'max_enrich': '0.041'}}}, 
            {'name': 'reactor', 
             'config': {'Reactor': {'fuel_incommods': {'val': 'c_leu'}, 
                                    'fuel_inrecipes': {'val': 'r_leu'}, 
                                    'fuel_outcommods': {'val': 'c_spent_leu'}, 
                                    'fuel_outrecipes': {'val': 'r_leu_spent'}, 
                                    'cycle_time': '180', 'refuel_time': '30', 
                                    'assem_size': '3300', 'n_assem_core': '3', 
                                    'n_assem_batch': '1', 'power_cap': '100'}}}, 
            {'name': 'separations', 
             'config': {'Separations': {'feed_commods': {'val': 'c_spent_leu'}, 
                                        'feedbuf_size': 50.0}, 
                                        "streams": {
                                          "item": [{
                                            "commod": "c_placeholder1",
                                            "info": {
                                              "buf_size": 0.0,
                                              "efficiencies": {
                                                "item": [{
                                                  "comp": 0,
                                                  "eff": 0.0},
                                                  {"comp": 0,
                                                  "eff": 0.0},
                                              ]}
                                              }
                                            },
                                            {"commod": "c_placeholder2",
                                            "info": {
                                              "buf_size": 0.0,
                                              "efficiencies": {
                                                "item": [{
                                                  "comp": 0,
                                                  "eff": 0.0},
                                                  {"comp": 0,
                                                  "eff": 0.0},
                                              ]}
                                              }
                                            },
                                        ]}}}
            {'name': 'SpentFuelSink', 
             'config': {'Sink': {'in_commods': {'val': 'c_spent_leu'}}}}, 
        ], 
        'region': {'name': 'SimpleHiderRegion', 
                   'config': {'NullRegion': None}, 
                   'institution': {'name': 'inst', 
                                   'initialfacilitylist': {'entry': [{'number': 1, 'prototype': 'UraniumMine'}, 
                                                                     {'number': 1, 'prototype': 'LEUenrich'}, 
                                                                     {'number': 1, 'prototype': 'reactor'}, 
                                                                     {'number': 1, 'prototype': 'separations'},
                                                                     {'number': 1, 'prototype': 'SpentFuelSink'}]}, 
                                   'config': {'NullInst': None}}
                  }, 
        'recipe': [
            {'name': 'r_nat_u', 'basis': 'mass', 
             'nuclide': [{'id': '92235', 'comp': '0.00711'}, 
                         {'id': '92238', 'comp': '0.99289'}]}, 
            {'name': 'r_leu', 'basis': 'mass', 
             'nuclide': [{'id': '92235', 'comp': '0.04'}, 
                         {'id': '92238', 'comp': '0.96'}]}, 
            {'name': 'r_leu_spent', 'basis': 'mass', 
             'nuclide': [{'id': '92235', 'comp': '0.01'}, 
                         {'id': '92238', 'comp': '0.94'}, 
                         {'id': '94239', 'comp': '0.01'}, 
                         {'id': '55135', 'comp': '0.3'}]}
        ]
    }
}
